# %%
import pandas as pd
import numpy as np
import re
import math

# %%
#DECLARACION DE FUNCIONES

def asignar_precio(dato):
    
    if type(dato) == str:
        dato = dato.lower()

        if 'free' in dato:
            return float(0)#Si el dato contiene la palabra free se le asigna un precio $0
        
        if 'starting' in dato:
            precio = '0'
            precio = re.findall(r'\$(\S+)', dato)
            precio = ''.join(precio)
            precio = float(precio)#Si el dato contiene la palabra starting y un valor numerico devuelve dicho valor, en el caso que no haya valor numerico devolvera 0
            return precio
        return float(0)
        
    return dato

def extraer_anio(dato):
    anio = '1900'
    if type(dato) == str:
        anio = re.findall(r'\d{4}', dato)
        anio= ''.join(anio)       
        return anio
    return dato

def transformar_lista(dato):
    if type(dato) == list:
        dato = ' - '.join(dato)
        reemplazos = ["{", "}", "'", " ", '[', ']', ':', ',', '"']
        for elemento in reemplazos:
            dato = dato.replace(elemento, "")
        return dato
    else:
        return dato

# %%
#Se crea el dataframe df_steam_games con pandas accediendo directamente al archivo json ya que el mismo esta correcto
df1 = pd.read_json("C:/Users/eduen/AppData/Local/Temp/steam_games.json.gz", lines=True, compression='gzip')

# %%
df_steam_games = df1

# %%
#Eliminar las columnas 'user_id', 'steam_id', 'items', 'items_count' y 'metascore'
df_steam_games = df_steam_games.drop(columns=['user_id', 'steam_id', 'items', 'items_count', 'metascore'])
#Eliminar todas las filas en la que la variable 'title' posea valores nulos
df_steam_games = df_steam_games.dropna(subset=['title'])
#Eliminar filas repetidas en funcion del campo 'title'
df_steam_games = df_steam_games.drop_duplicates(subset=['title'])
#Reemplazar los valores tipo str por numericos en el campo 'price'
df_steam_games['price'] = df_steam_games['price'].apply(asignar_precio)
#Reemplazar valores nulos por la media en 'price'
df_steam_games['price'] = df_steam_games['price'].fillna(df_steam_games['price'].mean())
#Extraer año de fechas
df_steam_games['release_date'] = df_steam_games['release_date'].apply(extraer_anio)
#Campo 'release_date' a formato fecha
df_steam_games['release_date'] = pd.to_datetime(df_steam_games['release_date'], format= '%Y', errors= 'coerce').dt.year
df_steam_games['release_date'].fillna(1900, inplace= True)
df_steam_games['release_date'] = df_steam_games['release_date'].astype(int)
#Reemplazar datos nulos de variables categoricas por la leyenda 'Dato Desconocido'
df_steam_games['publisher'].fillna('Dato Desconocido', inplace= True)
df_steam_games['genres'].fillna('Dato Desconocido', inplace= True)
df_steam_games['tags'].fillna('Dato Desconocido', inplace= True)
df_steam_games['reviews_url'].fillna('Dato Desconocido', inplace= True)
df_steam_games['specs'].fillna('Dato Desconocido', inplace= True)
df_steam_games['developer'].fillna('Dato Desconocido', inplace= True)
df_steam_games['id'].fillna(df_steam_games['id'].max() + 1, inplace= True)
#Reemplazar datos nulos por cero en 'discount_price'
df_steam_games['discount_price'].fillna(0, inplace= True)
#Extraer datos de listas
df_steam_games = df_steam_games.map(transformar_lista)
#
df_steam_games['publisher'] = df_steam_games['publisher'].astype(str)

print(df_steam_games['genres'].unique())
# Out:
# ['Action-Casual-Indie-Simulation-Strategy' 'FreetoPlay-Indie-RPG-Strategy'
#  'Casual-FreetoPlay-Indie-Simulation-Sports' 'Action-Adventure-Casual'
#  'Action-Adventure-Simulation' 'FreetoPlay-Indie-Simulation-Sports'
#  'Casual-Indie-Racing-Simulation' 'Action-Indie-Simulation-EarlyAccess'
#  'Action-Adventure-Casual-Indie-RPG' 'Casual-Indie'
#  'Casual-Indie-Simulation' 'Adventure-Casual-Indie-Simulation-Strategy'
#  'Action-Adventure-Indie' 'Racing-Simulation-Sports' 'Action-Indie'
#  'Dato Desconocido' 'Action-Indie-Racing' 'Action' 'Action-Indie-RPG'
#  'Casual-Indie-Strategy'
#  'Action-Casual-Indie-MassivelyMultiplayer-Simulation-Sports-Strategy'
#  'Adventure-Casual-Indie' 'Action-Adventure-RPG'
#  'Adventure-Casual-Indie-RPG' 'Strategy'
#  'Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Adventure-FreetoPlay-RPG-EarlyAccess'
#  'Action-Indie-Strategy-EarlyAccess' 'Action-Adventure-Indie-RPG-Strategy'
#  'Action-Adventure-Indie-RPG' 'Casual-Strategy-EarlyAccess'
#  'Adventure-Casual-FreetoPlay-Indie' 'Indie-Strategy' 'Indie-Simulation'
#  'Racing' 'Adventure-RPG' 'Action-Adventure' 'RPG' 'Indie-RPG'
#  'Action-RPG' 'Casual' 'RPG-Casual-Adventure' 'Action-Adventure-Strategy'
#  'Simulation' 'Simulation-Strategy' 'Casual-Simulation' 'Adventure'
#  'Sports' 'Adventure-Indie' 'Indie' 'Strategy-Simulation' 'RPG-Strategy'
#  'Indie-Casual' 'Action-Simulation-Strategy' 'Indie-Casual-Sports'
#  'Action-Indie-Strategy' 'Strategy-Indie' 'Casual-Strategy'
#  'RPG-MassivelyMultiplayer' 'MassivelyMultiplayer-RPG'
#  'Indie-Simulation-Strategy' 'Action-Simulation' 'Simulation-Sports'
#  'Action-Adventure-Racing-Simulation-Strategy' 'Action-Racing'
#  'Action-Casual' 'Adventure-Casual' 'Action-RPG-Indie'
#  'Strategy-Indie-Simulation' 'Action-FreetoPlay-Indie' 'Strategy-Casual'
#  'Action-Casual-Indie' 'Action-Adventure-Casual-RPG' 'Strategy-RPG'
#  'RPG-Casual' 'RPG-Indie' 'Action-RPG-MassivelyMultiplayer'
#  'Adventure-Casual-Simulation' 'Adventure-Casual-Indie-Simulation'
#  'Indie-RPG-Strategy' 'Indie-Racing' 'RPG-Simulation-Strategy'
#  'Action-Strategy-Indie-Sports' 'Casual-Indie-Simulation-Strategy'
#  'FreetoPlay-MassivelyMultiplayer-RPG' 'Action-Casual-Indie-Strategy'
#  'Adventure-Indie-RPG' 'Action-FreetoPlay'
#  'Action-Adventure-FreetoPlay-Indie-MassivelyMultiplayer-RPG'
#  'Adventure-Strategy-RPG-Indie' 'Action-Indie-RPG-Strategy'
#  'Adventure-Casual-FreetoPlay-MassivelyMultiplayer-Strategy'
#  'Action-Indie-Racing-Strategy' 'Action-MassivelyMultiplayer-Simulation'
#  'Racing-Simulation' 'Strategy-Indie-Casual-Simulation'
#  'Casual-Simulation-Strategy' 'Adventure-Casual-RPG'
#  'Action-Adventure-FreetoPlay-MassivelyMultiplayer-RPG'
#  'Adventure-Strategy' 'Strategy-RPG-Indie'
#  'Action-FreetoPlay-MassivelyMultiplayer' 'Casual-Indie-RPG'
#  'Casual-Indie-Racing' 'RPG-Simulation'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-RPG' 'Action-Indie-Casual'
#  'Adventure-Indie-Strategy' 'Action-RPG-Strategy'
#  'Indie-Simulation-Strategy-EarlyAccess' 'Action-Strategy-RPG-Indie'
#  'Action-Casual-Simulation-Strategy' 'Action-Strategy-Indie-Casual'
#  'Adventure-Casual-FreetoPlay-Indie-RPG'
#  'Animation&amp;Modeling-VideoProduction' 'Action-Strategy'
#  'Action-Indie-Simulation-Strategy' 'Animation&amp;Modeling'
#  'Action-Adventure-Strategy-RPG-Indie' 'Action-Adventure-Indie-Simulation'
#  'Action-Indie-Simulation'
#  'Action-Adventure-Casual-FreetoPlay-MassivelyMultiplayer-RPG-Simulation'
#  'Strategy-Indie-Casual' 'Action-Strategy-Indie' 'Action-Strategy-Casual'
#  'Utilities' 'Action-Adventure-Indie-Strategy' 'RPG-WebPublishing'
#  'Action-FreetoPlay-MassivelyMultiplayer-RPG'
#  'Adventure-Casual-Indie-RPG-Simulation' 'Adventure-Indie-Simulation'
#  'Action-FreetoPlay-Indie-Strategy' 'Indie-Simulation-Sports-Strategy'
#  'MassivelyMultiplayer' 'Casual-Sports'
#  'Education-SoftwareTraining-Utilities-WebPublishing'
#  'Design&amp;Illustration-WebPublishing' 'Casual-Indie-RPG-Strategy'
#  'Racing-Sports' 'Adventure-Indie-RPG-Strategy'
#  'Action-FreetoPlay-MassivelyMultiplayer-Simulation'
#  'Action-Adventure-Casual-Indie'
#  'FreetoPlay-MassivelyMultiplayer-Simulation'
#  'Action-Adventure-Indie-RPG-EarlyAccess'
#  'Action-Racing-Simulation-Sports' 'Action-Adventure-Casual-Strategy'
#  'FreetoPlay-Indie-Simulation-Sports-EarlyAccess'
#  'Action-Adventure-RPG-Simulation-Strategy' 'Action-RPG-Simulation'
#  'Adventure-Casual-Indie-RPG-Strategy' 'Indie-RPG-Simulation-Strategy'
#  'Indie-RPG-Simulation-EarlyAccess' 'FreetoPlay-Simulation'
#  'Action-Indie-RPG-EarlyAccess' 'Action-Indie-Sports'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-SoftwareTraining-Utilities'
#  'Adventure-FreetoPlay-Indie' 'Design&amp;Illustration'
#  'Animation&amp;Modeling-Education-Utilities-WebPublishing'
#  'Adventure-FreetoPlay-Indie-MassivelyMultiplayer-RPG-Strategy'
#  'Action-Adventure-FreetoPlay-Indie' 'Action-Casual-Indie-Simulation'
#  'Action-Adventure-Indie-MassivelyMultiplayer-RPG'
#  'Indie-MassivelyMultiplayer-Strategy' 'Adventure-RPG-Strategy'
#  'Education-SoftwareTraining' 'Casual-FreetoPlay-Indie'
#  'Action-Adventure-Casual-Racing'
#  'Casual-Animation&amp;Modeling-AudioProduction-Utilities'
#  'Animation&amp;Modeling-WebPublishing' 'AudioProduction-Utilities'
#  'Adventure-FreetoPlay-Indie-RPG' 'Action-Racing-EarlyAccess'
#  'Casual-Indie-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration'
#  'AudioProduction-Utilities-VideoProduction'
#  'FreetoPlay-Indie-MassivelyMultiplayer-RPG' 'Casual-Racing'
#  'Action-Adventure-Indie-Racing' 'Action-Indie-EarlyAccess'
#  'Action-EarlyAccess-Indie' 'Indie-Racing-Sports' 'Action-Racing-Sports'
#  'Casual-RPG' 'Action-Casual-Indie-EarlyAccess'
#  'Action-Casual-Indie-Racing-Simulation' 'FreetoPlay-Indie-Strategy'
#  'Action-Racing-Simulation-Strategy' 'Casual-Indie-RPG-Simulation'
#  'Action-Adventure-Casual-FreetoPlay-RPG'
#  'Action-Adventure-Indie-Simulation-EarlyAccess'
#  'Action-Indie-MassivelyMultiplayer-RPG-Simulation'
#  'Adventure-Casual-Indie-RPG-Simulation-Strategy-EarlyAccess'
#  'Action-Casual-Indie-Sports' 'Action-Adventure-Casual-Indie-Strategy'
#  'Action-Casual-FreetoPlay-Indie-MassivelyMultiplayer-EarlyAccess'
#  'Casual-FreetoPlay-Indie-Simulation-Strategy'
#  'Indie-Strategy-EarlyAccess' 'Adventure-Indie-RPG-Simulation-Strategy'
#  'Adventure-Indie-RPG-Simulation' 'Action-MassivelyMultiplayer-RPG'
#  'Design&amp;Illustration-PhotoEditing'
#  'Action-Adventure-FreetoPlay-Indie-MassivelyMultiplayer-RPG-Strategy'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer'
#  'Action-Adventure-FreetoPlay-Indie-RPG'
#  'Action-Indie-Racing-Simulation-Sports-EarlyAccess'
#  'Casual-FreetoPlay-Indie-MassivelyMultiplayer-Strategy' 'VideoProduction'
#  'Adventure-FreetoPlay-MassivelyMultiplayer-RPG-Strategy'
#  'Action-Adventure-RPG-Strategy' 'Simulation-Sports-Strategy'
#  'Indie-Simulation-EarlyAccess'
#  'Action-FreetoPlay-MassivelyMultiplayer-RPG-Strategy'
#  'Action-Indie-Simulation-Sports' 'Sports-Strategy'
#  'Action-Adventure-Racing' 'Action-Casual-FreetoPlay-MassivelyMultiplayer'
#  'Action-Casual-Strategy' 'Casual-FreetoPlay-Indie-Strategy'
#  'Adventure-Simulation' 'Action-Adventure-FreetoPlay-Simulation-Sports'
#  'Indie-Racing-Sports-EarlyAccess'
#  'Action-Adventure-Indie-MassivelyMultiplayer-RPG-Simulation-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-FreetoPlay-RPG-Strategy'
#  'Action-Adventure-Indie-RPG-Simulation-Strategy-EarlyAccess'
#  'Adventure-Indie-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-SoftwareTraining-Utilities-WebPublishing'
#  'MassivelyMultiplayer-RPG-EarlyAccess' 'Indie-EarlyAccess'
#  'FreetoPlay-Indie' 'Education' 'FreetoPlay-Strategy'
#  'Adventure-Indie-RPG-EarlyAccess'
#  'Adventure-Casual-Indie-RPG-EarlyAccess'
#  'Action-Adventure-Casual-FreetoPlay-Indie-RPG-Strategy'
#  'Action-Adventure-RPG-EarlyAccess' 'Action-Casual-Indie-Racing-Sports'
#  'Indie-MassivelyMultiplayer-Simulation-Strategy'
#  'Action-FreetoPlay-EarlyAccess'
#  'Casual-Indie-Simulation-Strategy-EarlyAccess' 'Action-Sports'
#  'Casual-FreetoPlay-Indie-Simulation'
#  'Design&amp;Illustration-Education-Utilities'
#  'Design&amp;Illustration-Education' 'Action-Adventure-Indie-EarlyAccess'
#  'Action-Adventure-Casual-Indie-RPG-Strategy'
#  'Action-FreetoPlay-Indie-RPG'
#  'Action-Adventure-Casual-Indie-RPG-EarlyAccess' 'FreetoPlay'
#  'Indie-MassivelyMultiplayer-RPG-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-SoftwareTraining-Utilities-EarlyAccess'
#  'Action-Adventure-Indie-Strategy-EarlyAccess'
#  'Action-MassivelyMultiplayer-Racing' 'Action-Indie-Racing-EarlyAccess'
#  'Adventure-Indie-MassivelyMultiplayer-RPG-Strategy'
#  'Animation&amp;Modeling-Design&amp;Illustration-Utilities-VideoProduction'
#  'Casual-Indie-Sports' 'Action-Casual-FreetoPlay-RPG-Simulation-Strategy'
#  'Action-Casual-RPG-Simulation-Strategy' 'Indie-Racing-Simulation-Sports'
#  'Action-Adventure-FreetoPlay-MassivelyMultiplayer'
#  'Simulation-Strategy-EarlyAccess' 'Action-FreetoPlay-RPG'
#  'Action-Adventure-Casual-Indie-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-FreetoPlay-MassivelyMultiplayer-RPG'
#  'Adventure-RPG-Strategy-EarlyAccess' 'Action-Casual-Indie-Racing'
#  'Action-Adventure-FreetoPlay' 'AudioProduction' 'Indie-RPG-Simulation'
#  'RPG-Strategy-EarlyAccess'
#  'Action-Casual-FreetoPlay-MassivelyMultiplayer-Sports'
#  'Adventure-RPG-Simulation-Strategy'
#  'Action-FreetoPlay-MassivelyMultiplayer-RPG-EarlyAccess'
#  'FreetoPlay-Racing-Simulation-Sports'
#  'Action-Adventure-Casual-Indie-Simulation'
#  'Design&amp;Illustration-Utilities-WebPublishing'
#  'Action-Adventure-Casual-FreetoPlay-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-VideoProduction'
#  'Action-Casual-Indie-Racing-Simulation-Sports' 'Casual-FreetoPlay'
#  'Indie-MassivelyMultiplayer-RPG-Strategy' 'Simulation-Sports-EarlyAccess'
#  'Action-Adventure-Casual-Indie-RPG-Simulation-Strategy' 'Indie-Sports'
#  'Adventure-Indie-Racing'
#  'Adventure-Casual-FreetoPlay-Indie-RPG-Simulation-Strategy'
#  'Action-FreetoPlay-Strategy' 'Action-FreetoPlay-RPG-Strategy'
#  'Casual-Indie-EarlyAccess' 'Action-Strategy-EarlyAccess'
#  'Casual-Simulation-Sports-Strategy'
#  'Action-Adventure-Indie-RPG-Simulation-Strategy'
#  'Racing-Simulation-EarlyAccess'
#  'Indie-Simulation-Sports-Strategy-EarlyAccess'
#  'Action-Adventure-Indie-MassivelyMultiplayer-Simulation-EarlyAccess'
#  'Casual-FreetoPlay-MassivelyMultiplayer-Simulation'
#  'Action-Indie-Sports-EarlyAccess' 'Action-Casual-Indie-RPG-Strategy'
#  'Animation&amp;Modeling-Design&amp;Illustration-Utilities'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-Utilities-EarlyAccess'
#  'Casual-FreetoPlay-Indie-RPG' 'Action-Indie-RPG-Simulation-EarlyAccess'
#  'Casual-Simulation-Sports'
#  'Action-Adventure-Casual-FreetoPlay-Indie-EarlyAccess'
#  'Action-MassivelyMultiplayer-EarlyAccess'
#  'Adventure-Casual-Indie-Strategy'
#  'Action-Adventure-Casual-Indie-Simulation-Strategy'
#  'Adventure-Indie-Simulation-Strategy' 'FreetoPlay-Simulation-Strategy'
#  'Action-Casual-Indie-RPG-EarlyAccess' 'Action-Indie-Racing-Sports'
#  'Action-Adventure-Casual-Indie-MassivelyMultiplayer-RPG-Simulation-Strategy'
#  'Casual-Racing-Sports' 'Casual-FreetoPlay-Strategy'
#  'Action-Adventure-Casual-Indie-Simulation-Sports'
#  'FreetoPlay-RPG-Strategy' 'Action-Indie-MassivelyMultiplayer'
#  'FreetoPlay-Sports' 'Adventure-Casual-Simulation-Strategy'
#  'Action-Simulation-Strategy-EarlyAccess'
#  'Action-Casual-FreetoPlay-Strategy' 'Action-Casual-FreetoPlay-Indie-RPG'
#  'Action-MassivelyMultiplayer-Racing-RPG-Simulation'
#  'Action-Casual-FreetoPlay-Indie-RPG-Strategy'
#  'Action-FreetoPlay-Indie-EarlyAccess' 'Casual-Indie-Sports-Strategy'
#  'Action-Casual-MassivelyMultiplayer'
#  'Action-Casual-Indie-RPG-Simulation-Strategy' 'Action-Casual-Indie-RPG'
#  'Action-Casual-Racing' 'Indie-Simulation-Sports-EarlyAccess'
#  'Action-Indie-Racing-Simulation' 'Action-Simulation-Sports'
#  'FreetoPlay-Indie-MassivelyMultiplayer-Strategy'
#  'Indie-RPG-Sports-Strategy-EarlyAccess'
#  'Adventure-Indie-Simulation-Strategy-EarlyAccess'
#  'Action-Indie-RPG-Strategy-EarlyAccess' 'Adventure-Casual-Indie-Sports'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-Simulation'
#  'Casual-Indie-Simulation-Sports-Strategy'
#  'Action-Casual-FreetoPlay-Indie'
#  'Action-Adventure-Casual-Indie-EarlyAccess'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-Sports' 'FreetoPlay-RPG'
#  'Adventure-Indie-MassivelyMultiplayer-RPG'
#  'Action-Adventure-Casual-Indie-RPG-Simulation-Strategy-EarlyAccess'
#  'Adventure-FreetoPlay' 'Action-Adventure-Casual-Indie-RPG-Simulation'
#  'FreetoPlay-MassivelyMultiplayer'
#  'Indie-RPG-Simulation-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-WebPublishing'
#  'Adventure-Indie-Strategy-EarlyAccess' 'Adventure-Casual-FreetoPlay'
#  'AudioProduction-Design&amp;Illustration-PhotoEditing-Utilities-VideoProduction-WebPublishing'
#  'Adventure-Indie-RPG-Simulation-EarlyAccess'
#  'Animation&amp;Modeling-Utilities' 'SoftwareTraining'
#  'FreetoPlay-Sports-Strategy' 'Action-Adventure-Casual-Indie-Racing'
#  'Action-FreetoPlay-Simulation-Strategy'
#  'Action-Adventure-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Indie-Racing-EarlyAccess' 'Action-Adventure-FreetoPlay-RPG-Simulation'
#  'Casual-FreetoPlay-Indie-RPG-Simulation-Strategy'
#  'Design&amp;Illustration-PhotoEditing-Utilities'
#  'Action-Casual-Indie-Simulation-Sports-EarlyAccess'
#  'Casual-Indie-MassivelyMultiplayer-Strategy'
#  'Action-Adventure-Indie-RPG-Strategy-EarlyAccess'
#  'Adventure-Casual-Indie-RPG-Simulation-Strategy'
#  'FreetoPlay-MassivelyMultiplayer-Strategy' 'Action-Indie-RPG-Simulation'
#  'Casual-FreetoPlay-Indie-Strategy-EarlyAccess' 'Adventure-EarlyAccess'
#  'FreetoPlay-MassivelyMultiplayer-Simulation-Sports'
#  'Indie-RPG-EarlyAccess' 'Action-Adventure-Simulation-EarlyAccess'
#  'Action-FreetoPlay-MassivelyMultiplayer-Simulation-Strategy'
#  'Action-Adventure-Indie-RPG-Simulation' 'Action-Adventure-Sports'
#  'AudioProduction-Education-SoftwareTraining-VideoProduction-WebPublishing'
#  'Action-Indie-Simulation-Strategy-EarlyAccess'
#  'Action-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Action-Adventure-Casual-Indie-RPG-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-Indie-MassivelyMultiplayer-Simulation'
#  'Adventure-Casual-Strategy'
#  'Casual-FreetoPlay-MassivelyMultiplayer-Sports-Strategy' 'Accounting'
#  'Action-RPG-EarlyAccess' 'Indie-MassivelyMultiplayer-RPG'
#  'Indie-Racing-Simulation-Sports-EarlyAccess'
#  'Action-Casual-FreetoPlay-Indie-Strategy'
#  'FreetoPlay-Indie-MassivelyMultiplayer-Simulation-Sports-Strategy'
#  'Action-Adventure-Casual-Indie-Simulation-Strategy-EarlyAccess'
#  'FreetoPlay-Indie-MassivelyMultiplayer-RPG-Strategy-EarlyAccess'
#  'Adventure-Casual-Indie-EarlyAccess'
#  'AudioProduction-SoftwareTraining-Utilities-VideoProduction-WebPublishing'
#  'Action-Adventure-MassivelyMultiplayer-EarlyAccess'
#  'Adventure-Casual-FreetoPlay-Indie-MassivelyMultiplayer-RPG-Strategy'
#  'Indie-RPG-Strategy-EarlyAccess' 'Casual-Indie-RPG-Simulation-Strategy'
#  'Casual-Indie-RPG-Simulation-Sports-Strategy'
#  'FreetoPlay-Indie-MassivelyMultiplayer-RPG-Strategy'
#  'FreetoPlay-MassivelyMultiplayer-RPG-Strategy'
#  'FreetoPlay-Indie-RPG-Simulation'
#  'Action-Casual-Indie-Simulation-Sports-Strategy'
#  'FreetoPlay-Indie-RPG-Strategy-EarlyAccess'
#  'Action-Adventure-Indie-Racing-Simulation-Sports'
#  'Action-Adventure-Casual-Racing-RPG-Sports-Strategy'
#  'FreetoPlay-Indie-Simulation-EarlyAccess'
#  'Adventure-Indie-Simulation-EarlyAccess'
#  'Adventure-FreetoPlay-Indie-RPG-EarlyAccess'
#  'Action-Adventure-Indie-Simulation-Strategy' 'Casual-RPG-Simulation'
#  'Strategy-EarlyAccess' 'Casual-FreetoPlay-Simulation'
#  'FreetoPlay-MassivelyMultiplayer-Simulation-Strategy'
#  'Action-Adventure-Indie-Racing-EarlyAccess'
#  'AudioProduction-SoftwareTraining-Utilities'
#  'Action-MassivelyMultiplayer' 'Action-Casual-Simulation'
#  'Sports-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-AudioProduction-SoftwareTraining-Utilities-VideoProduction'
#  'Adventure-FreetoPlay-MassivelyMultiplayer-RPG'
#  'Action-Casual-Indie-Sports-EarlyAccess'
#  'Action-Casual-FreetoPlay-Indie-Sports-EarlyAccess'
#  'Casual-FreetoPlay-RPG'
#  'Action-Adventure-Indie-MassivelyMultiplayer-Simulation'
#  'Action-Indie-Racing-Simulation-Sports'
#  'Action-Adventure-MassivelyMultiplayer-RPG-Simulation-Strategy'
#  'Action-Adventure-Indie-Racing-Sports-Strategy'
#  'Action-Adventure-Casual-Indie-Racing-Simulation'
#  'Animation&amp;Modeling-Design&amp;Illustration-Utilities-EarlyAccess'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-RPG-Simulation'
#  'Casual-FreetoPlay-Simulation-Sports' 'Utilities-VideoProduction'
#  'Indie-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Casual-FreetoPlay-MassivelyMultiplayer-Strategy'
#  'Adventure-Casual-RPG-Strategy'
#  'Action-Indie-MassivelyMultiplayer-EarlyAccess'
#  'Action-Casual-FreetoPlay-Indie-RPG-Sports-EarlyAccess'
#  'Action-Indie-Racing-Simulation-Sports-Strategy'
#  'Indie-Racing-Simulation' 'Design&amp;Illustration-Utilities'
#  'WebPublishing' 'Action-Adventure-FreetoPlay-Indie-EarlyAccess'
#  'Action-Casual-FreetoPlay-Indie-RPG-Sports'
#  'Action-Casual-MassivelyMultiplayer-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Sports-EarlyAccess'
#  'Adventure-MassivelyMultiplayer-RPG'
#  'Action-Adventure-Casual-Racing-Simulation-Sports'
#  'Action-Casual-Indie-Simulation-Sports' 'Action-Casual-FreetoPlay'
#  'Casual-FreetoPlay-MassivelyMultiplayer-RPG-Simulation-Strategy'
#  'Action-Adventure-Indie-RPG-Simulation-Sports'
#  'Casual-FreetoPlay-Indie-Simulation-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-FreetoPlay-Indie-MassivelyMultiplayer-RPG-Simulation'
#  'Action-Casual-Indie-MassivelyMultiplayer-Simulation-Strategy-EarlyAccess'
#  'Action-EarlyAccess'
#  'FreetoPlay-Indie-MassivelyMultiplayer-RPG-Simulation-Strategy'
#  'Adventure-FreetoPlay-RPG-Strategy'
#  'Action-Casual-FreetoPlay-Indie-Simulation-Sports-Strategy'
#  'Casual-FreetoPlay-Indie-Simulation-Sports-Strategy'
#  'Action-Adventure-Strategy-EarlyAccess'
#  'Action-Adventure-MassivelyMultiplayer'
#  'Design&amp;Illustration-Education-PhotoEditing-SoftwareTraining'
#  'Indie-MassivelyMultiplayer-RPG-Simulation' 'Indie-Racing-RPG-Sports'
#  'Adventure-Casual-RPG-EarlyAccess' 'FreetoPlay-Indie-Simulation'
#  'Action-FreetoPlay-Racing-Sports' 'Casual-Indie-Simulation-EarlyAccess'
#  'Casual-RPG-Strategy-EarlyAccess' 'Action-Casual-Strategy-EarlyAccess'
#  'Action-Adventure-Indie-MassivelyMultiplayer-RPG-Simulation-EarlyAccess'
#  'FreetoPlay-Racing-Simulation-Sports-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Sports'
#  'Action-Casual-FreetoPlay-Indie-MassivelyMultiplayer'
#  'Action-Casual-Indie-MassivelyMultiplayer'
#  'FreetoPlay-Indie-Racing-Sports'
#  'Action-Adventure-Casual-FreetoPlay-Indie-Simulation-Sports-Strategy'
#  'Action-Simulation-Sports-Strategy'
#  'Action-Adventure-Casual-MassivelyMultiplayer'
#  'Action-Adventure-FreetoPlay-Sports-Strategy' 'PhotoEditing'
#  'Action-FreetoPlay-Indie-Simulation'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Simulation-EarlyAccess'
#  'Casual-FreetoPlay-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Action-Casual-FreetoPlay-RPG' 'Casual-EarlyAccess'
#  'Action-Casual-Simulation-Sports-Strategy'
#  'Casual-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'AudioProduction-Design&amp;Illustration-Utilities-VideoProduction'
#  'Action-Casual-Indie-MassivelyMultiplayer-Simulation-Sports'
#  'Casual-Indie-RPG-EarlyAccess' 'Adventure-Simulation-EarlyAccess'
#  'Action-Casual-Indie-Simulation-Strategy-EarlyAccess'
#  'Adventure-Casual-FreetoPlay-Indie-Simulation-Sports-Strategy'
#  'Casual-FreetoPlay-MassivelyMultiplayer-Simulation-Sports'
#  'Adventure-FreetoPlay-RPG' 'Indie-Racing-RPG-Simulation'
#  'Action-Adventure-Casual-Indie-RPG-Sports'
#  'FreetoPlay-Indie-Strategy-EarlyAccess'
#  'Action-Casual-Indie-RPG-Sports-Strategy-EarlyAccess'
#  'Indie-MassivelyMultiplayer-RPG-Simulation-Strategy'
#  'Action-Indie-Sports-Strategy-EarlyAccess'
#  'Design&amp;Illustration-PhotoEditing-SoftwareTraining-Utilities-VideoProduction'
#  'AudioProduction-SoftwareTraining-Utilities-VideoProduction'
#  'Action-Adventure-Casual-FreetoPlay-Indie-RPG'
#  'Casual-FreetoPlay-Indie-RPG-Simulation-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-SoftwareTraining-VideoProduction-WebPublishing'
#  'Action-FreetoPlay-MassivelyMultiplayer-Simulation-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-Sports'
#  'Casual-Indie-Sports-EarlyAccess'
#  'MassivelyMultiplayer-Racing-Simulation-Sports' 'Casual-RPG-Strategy'
#  'Design&amp;Illustration-PhotoEditing-VideoProduction'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-SoftwareTraining-Utilities-VideoProduction-WebPublishing'
#  'Action-FreetoPlay-Indie-Racing-Sports-Strategy'
#  'Adventure-Simulation-Sports'
#  'Casual-Indie-Simulation-Sports-EarlyAccess'
#  'Adventure-Casual-Indie-Simulation-Sports-Strategy'
#  'Action-Adventure-FreetoPlay-MassivelyMultiplayer-RPG-Strategy'
#  'Action-Casual-FreetoPlay-MassivelyMultiplayer-Sports-Strategy'
#  'Action-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Action-Casual-Indie-Strategy-EarlyAccess'
#  'Design&amp;Illustration-Education-PhotoEditing-SoftwareTraining-Utilities'
#  'Design&amp;Illustration-EarlyAccess'
#  'Adventure-Indie-RPG-Strategy-EarlyAccess'
#  'Adventure-Casual-FreetoPlay-Indie-Simulation'
#  'Action-Indie-RPG-Simulation-Strategy'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-Utilities-WebPublishing'
#  'Adventure-Casual-Indie-Racing-Simulation'
#  'Action-Casual-Indie-Simulation-EarlyAccess' 'Simulation-EarlyAccess'
#  'Casual-Indie-Racing-Sports-EarlyAccess'
#  'Action-FreetoPlay-MassivelyMultiplayer-EarlyAccess'
#  'Utilities-EarlyAccess' 'Action-Indie-MassivelyMultiplayer-Simulation'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-PhotoEditing-SoftwareTraining-VideoProduction'
#  'MassivelyMultiplayer-RPG-Strategy'
#  'Casual-Indie-RPG-Simulation-Strategy-EarlyAccess'
#  'Action-Indie-MassivelyMultiplayer-RPG-Simulation-EarlyAccess'
#  'Sports-EarlyAccess' 'Adventure-Strategy-EarlyAccess'
#  'Action-RPG-Simulation-Strategy'
#  'Action-Indie-MassivelyMultiplayer-Simulation-Strategy'
#  'Adventure-Casual-Indie-Racing'
#  'Casual-FreetoPlay-MassivelyMultiplayer-RPG'
#  'Action-FreetoPlay-Indie-RPG-Strategy'
#  'Action-Adventure-FreetoPlay-MassivelyMultiplayer-RPG-Simulation'
#  'Action-Adventure-FreetoPlay-Indie-RPG-Strategy'
#  'Adventure-Casual-Indie-RPG-Simulation-EarlyAccess'
#  'Action-Adventure-Simulation-Strategy'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-Strategy'
#  'FreetoPlay-Simulation-Sports'
#  'Action-Casual-Indie-MassivelyMultiplayer-Strategy'
#  'Adventure-Simulation-Strategy'
#  'Action-Indie-MassivelyMultiplayer-Strategy'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-Utilities'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-RPG-Strategy'
#  'Animation&amp;Modeling-AudioProduction-Design&amp;Illustration-Utilities-VideoProduction-WebPublishing'
#  'Action-FreetoPlay-MassivelyMultiplayer-Racing'
#  'Action-Adventure-MassivelyMultiplayer-RPG'
#  'Casual-FreetoPlay-MassivelyMultiplayer-Sports'
#  'Adventure-Casual-Indie-Sports-Strategy'
#  'Action-Adventure-FreetoPlay-RPG' 'FreetoPlay-Indie-EarlyAccess'
#  'Indie-Sports-EarlyAccess'
#  'Adventure-Casual-Indie-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Utilities-WebPublishing' 'Racing-Simulation-Sports-Strategy'
#  'Adventure-Casual-Indie-MassivelyMultiplayer-RPG-Strategy-EarlyAccess'
#  'Casual-RPG-Simulation-Strategy'
#  'Action-MassivelyMultiplayer-Racing-Simulation-EarlyAccess'
#  'Action-MassivelyMultiplayer-Racing-Simulation-Sports'
#  'Action-MassivelyMultiplayer-Racing-Simulation'
#  'Adventure-Casual-Indie-RPG-Simulation-Sports'
#  'Action-Adventure-Indie-Sports' 'Casual-Indie-Racing-Strategy'
#  'Action-Adventure-Indie-MassivelyMultiplayer-RPG-Strategy'
#  'Adventure-Indie-Sports'
#  'Adventure-Casual-FreetoPlay-Strategy-EarlyAccess'
#  'Action-Indie-Racing-Sports-EarlyAccess'
#  'FreetoPlay-Indie-Simulation-Strategy-EarlyAccess'
#  'Action-Adventure-Racing-RPG' 'FreetoPlay-Strategy-EarlyAccess'
#  'RPG-EarlyAccess' 'Action-Casual-Indie-Racing-EarlyAccess'
#  'Casual-FreetoPlay-Indie-MassivelyMultiplayer'
#  'Action-Casual-Indie-RPG-Simulation'
#  'Action-Adventure-Casual-Indie-MassivelyMultiplayer-Racing-RPG-Simulation-Sports-Strategy'
#  'Casual-FreetoPlay-Indie-Simulation-EarlyAccess'
#  'Action-Adventure-FreetoPlay-Indie-MassivelyMultiplayer-Racing-RPG-Strategy-EarlyAccess'
#  'Adventure-FreetoPlay-MassivelyMultiplayer-Strategy'
#  'Indie-Racing-Simulation-EarlyAccess'
#  'Adventure-Casual-Indie-Racing-Simulation-EarlyAccess'
#  'Accounting-Utilities' 'Action-Adventure-Indie-Racing-Simulation'
#  'Adventure-Casual-Indie-Racing-Simulation-Sports-EarlyAccess'
#  'Action-Casual-FreetoPlay-Indie-Simulation-Strategy'
#  'Indie-Sports-Strategy'
#  'Action-Adventure-Casual-Indie-Racing-Simulation-Sports-Strategy'
#  'Action-Adventure-Casual-Indie-MassivelyMultiplayer-Strategy'
#  'Action-Adventure-Casual-Indie-Simulation-Sports-Strategy'
#  'Casual-Indie-Sports-Strategy-EarlyAccess' 'Action-FreetoPlay-Simulation'
#  'Animation&amp;Modeling-AudioProduction-Design&amp;Illustration-SoftwareTraining-VideoProduction'
#  'Adventure-Casual-Indie-Racing-RPG-Simulation-Sports-Strategy'
#  'Casual-Indie-Simulation-Sports' 'Indie-MassivelyMultiplayer'
#  'Education-Utilities' 'Action-FreetoPlay-Strategy-EarlyAccess'
#  'Action-Indie-Sports-Strategy'
#  'Adventure-Casual-Indie-RPG-Simulation-Sports-Strategy'
#  'FreetoPlay-Indie-RPG' 'Action-MassivelyMultiplayer-RPG-Strategy'
#  'Action-Adventure-Casual-Indie-Racing-Simulation-Sports'
#  'Casual-Indie-MassivelyMultiplayer-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-Sports-Strategy'
#  'Action-Casual-FreetoPlay-MassivelyMultiplayer-Simulation-Strategy'
#  'Casual-Indie-Racing-Sports'
#  'Action-Adventure-FreetoPlay-Indie-Simulation'
#  'AudioProduction-Education-Utilities-VideoProduction'
#  'Action-Adventure-FreetoPlay-Indie-MassivelyMultiplayer'
#  'Indie-MassivelyMultiplayer-Simulation-Sports-EarlyAccess'
#  'Indie-RPG-Simulation-Sports-Strategy-EarlyAccess'
#  'Adventure-Casual-FreetoPlay-MassivelyMultiplayer-RPG'
#  'Adventure-FreetoPlay-Indie-Strategy-EarlyAccess'
#  'Adventure-Casual-EarlyAccess' 'Action-Casual-RPG-Strategy'
#  'Adventure-Casual-Indie-Racing-Simulation-Sports'
#  'Action-Casual-Indie-RPG-Sports'
#  'Action-Casual-FreetoPlay-Indie-Simulation-Sports'
#  'Adventure-Casual-Indie-Simulation-EarlyAccess'
#  'Adventure-Casual-Indie-Simulation-Sports'
#  'Adventure-FreetoPlay-Indie-RPG-Strategy'
#  'Adventure-Casual-Indie-RPG-Strategy-EarlyAccess'
#  'Casual-FreetoPlay-MassivelyMultiplayer'
#  'Action-Adventure-FreetoPlay-RPG-EarlyAccess'
#  'Adventure-Casual-Indie-Racing-RPG-Simulation-Strategy'
#  'Indie-RPG-Simulation-Sports-Strategy' 'Indie-RPG-Simulation-Sports'
#  'Action-Adventure-Casual-Indie-Racing-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-RPG'
#  'Action-Adventure-Indie-Simulation-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-FreetoPlay-MassivelyMultiplayer-Simulation-Sports'
#  'Adventure-Casual-MassivelyMultiplayer-Simulation'
#  'Indie-MassivelyMultiplayer-Simulation-EarlyAccess' 'Action-Casual-RPG'
#  'RPG-Simulation-EarlyAccess' 'Casual-Simulation-Strategy-EarlyAccess'
#  'FreetoPlay-Indie-Simulation-Strategy'
#  'Casual-Indie-MassivelyMultiplayer-Simulation-Sports-Strategy'
#  'Adventure-Casual-Indie-Racing-RPG-Simulation-Strategy-EarlyAccess'
#  'FreetoPlay-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-Simulation-Sports-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-PhotoEditing-Utilities'
#  'Action-Adventure-FreetoPlay-Indie-Strategy'
#  'Action-Adventure-FreetoPlay-Indie-MassivelyMultiplayer-EarlyAccess'
#  'Action-Adventure-Indie-RPG-Simulation-EarlyAccess'
#  'Action-Indie-MassivelyMultiplayer-RPG'
#  'AudioProduction-Utilities-EarlyAccess' 'Adventure-Casual-RPG-Simulation'
#  'Adventure-FreetoPlay-Indie-RPG-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-AudioProduction-Design&amp;Illustration-Utilities-VideoProduction'
#  'Action-Adventure-Casual-RPG-Strategy-EarlyAccess'
#  'Design&amp;Illustration-Utilities-EarlyAccess'
#  'Action-Adventure-Casual-Simulation'
#  'Adventure-Indie-Racing-Strategy-EarlyAccess'
#  'Adventure-Indie-Racing-Simulation-EarlyAccess'
#  'Action-Casual-Indie-RPG-Strategy-EarlyAccess'
#  'Action-Indie-Racing-Simulation-EarlyAccess'
#  'Casual-Indie-MassivelyMultiplayer-Simulation-EarlyAccess'
#  'Action-FreetoPlay-MassivelyMultiplayer-Strategy'
#  'Action-Adventure-FreetoPlay-Indie-Simulation-Strategy'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-EarlyAccess'
#  'Indie-Simulation-AudioProduction-EarlyAccess'
#  'Action-Adventure-Indie-MassivelyMultiplayer-Strategy'
#  'Action-FreetoPlay-Indie-Racing-Simulation-Sports-EarlyAccess'
#  'Casual-Simulation-EarlyAccess' 'Action-RPG-Strategy-EarlyAccess'
#  'RPG-Simulation-Strategy-EarlyAccess' 'Casual-FreetoPlay-Indie-Sports'
#  'Action-Adventure-EarlyAccess'
#  'Action-Casual-FreetoPlay-Strategy-EarlyAccess' 'Indie-Racing-Strategy'
#  'Adventure-FreetoPlay-Indie-MassivelyMultiplayer-RPG-Strategy-EarlyAccess'
#  'Adventure-FreetoPlay-Indie-MassivelyMultiplayer-RPG'
#  'Animation&amp;Modeling-Utilities-VideoProduction-EarlyAccess'
#  'FreetoPlay-Racing-Simulation-EarlyAccess'
#  'Action-Indie-Simulation-Sports-EarlyAccess' 'Education-EarlyAccess'
#  'Action-Adventure-FreetoPlay-Indie-Strategy-EarlyAccess'
#  'Accounting-Animation&amp;Modeling-AudioProduction-Design&amp;Illustration-Education-PhotoEditing-SoftwareTraining-Utilities-VideoProduction-WebPublishing'
#  'AudioProduction-VideoProduction' 'Casual-FreetoPlay-Sports-Strategy'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-Simulation-Strategy-EarlyAccess'
#  'Action-Casual-Indie-Racing-Simulation-Sports-EarlyAccess'
#  'Action-FreetoPlay-Sports' 'Action-Adventure-Casual-RPG-EarlyAccess'
#  'Action-Casual-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Action-Casual-Indie-Sports-Strategy'
#  'Action-Adventure-Casual-Indie-MassivelyMultiplayer'
#  'Action-Casual-Simulation-EarlyAccess'
#  'Action-MassivelyMultiplayer-RPG-Simulation' 'Racing-EarlyAccess'
#  'Action-Casual-MassivelyMultiplayer-Racing-Simulation-Sports'
#  'Action-Adventure-Casual-FreetoPlay-Indie-MassivelyMultiplayer-EarlyAccess'
#  'Action-Casual-Sports'
#  'Action-Adventure-Casual-Indie-Racing-Sports-EarlyAccess'
#  'Action-Indie-Animation&amp;Modeling-Design&amp;Illustration'
#  'Adventure-FreetoPlay-Simulation'
#  'Adventure-Casual-Indie-Simulation-Strategy-EarlyAccess'
#  'Action-Adventure-MassivelyMultiplayer-RPG-Simulation-EarlyAccess'
#  'Action-Adventure-FreetoPlay-Strategy' 'Adventure-Racing-Sports'
#  'Adventure-RPG-Simulation' 'Utilities-VideoProduction-WebPublishing'
#  'Adventure-Indie-Racing-Simulation-Sports'
#  'Action-Adventure-Casual-FreetoPlay-Indie'
#  'Design&amp;Illustration-Utilities-WebPublishing-EarlyAccess'
#  'Action-Adventure-MassivelyMultiplayer-Racing-Simulation'
#  'Animation&amp;Modeling-Utilities-EarlyAccess'
#  'Adventure-FreetoPlay-Indie-Simulation' 'Adventure-FreetoPlay-Strategy'
#  'Action-Casual-MassivelyMultiplayer-Simulation-Strategy'
#  'FreetoPlay-RPG-EarlyAccess'
#  'Adventure-FreetoPlay-Indie-MassivelyMultiplayer'
#  'Adventure-Casual-RPG-Strategy-EarlyAccess'
#  'Action-Sports-Strategy-EarlyAccess'
#  'Action-Casual-FreetoPlay-Indie-Sports'
#  'Action-Adventure-Indie-Racing-Sports'
#  'Action-Adventure-Indie-Simulation-Sports-EarlyAccess'
#  'Action-Adventure-Casual-Indie-RPG-Simulation-EarlyAccess'
#  'Casual-Indie-Racing-Simulation-Sports'
#  'Indie-MassivelyMultiplayer-Racing-Simulation-EarlyAccess'
#  'Action-Casual-FreetoPlay-MassivelyMultiplayer-RPG'
#  'Casual-RPG-Simulation-EarlyAccess' 'Action-Adventure-RPG-Simulation'
#  'Action-Racing-Simulation'
#  'Action-Adventure-FreetoPlay-Indie-RPG-EarlyAccess'
#  'FreetoPlay-RPG-Simulation' 'Casual-FreetoPlay-RPG-EarlyAccess'
#  'Casual-FreetoPlay-Sports' 'FreetoPlay-Indie-MassivelyMultiplayer'
#  'MassivelyMultiplayer-Strategy-EarlyAccess' 'EarlyAccess'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-Racing-Simulation-EarlyAccess'
#  'Action-Adventure-Indie-Simulation-Sports'
#  'Action-Adventure-Indie-Racing-Strategy' 'Indie-Simulation-Sports'
#  'Action-Casual-Indie-MassivelyMultiplayer-Simulation'
#  'Action-Adventure-MassivelyMultiplayer-RPG-Strategy-EarlyAccess'
#  'Action-Casual-FreetoPlay-MassivelyMultiplayer-RPG-Strategy'
#  'Design&amp;Illustration-PhotoEditing-WebPublishing'
#  'Adventure-Indie-MassivelyMultiplayer' 'Indie-Racing-Simulation-Strategy'
#  'Racing-Simulation-Strategy'
#  'AudioProduction-Education-SoftwareTraining-Utilities-VideoProduction'
#  'FreetoPlay-MassivelyMultiplayer-RPG-Strategy-EarlyAccess'
#  'Action-Casual-Indie-Racing-Simulation-EarlyAccess'
#  'Indie-MassivelyMultiplayer-Racing-Simulation-Sports'
#  'Action-FreetoPlay-Indie-Simulation-Strategy-EarlyAccess'
#  'Action-FreetoPlay-Indie-Simulation-Strategy'
#  'Adventure-MassivelyMultiplayer-RPG-Strategy'
#  'Action-RPG-Simulation-EarlyAccess'
#  'Action-Casual-Indie-Racing-RPG-Simulation-Strategy-EarlyAccess'
#  'Indie-Racing-Sports-Strategy-EarlyAccess'
#  'Utilities-VideoProduction-EarlyAccess'
#  'Action-Adventure-FreetoPlay-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'FreetoPlay-MassivelyMultiplayer-Racing'
#  'Action-Casual-FreetoPlay-Indie-EarlyAccess'
#  'Adventure-Simulation-Strategy-EarlyAccess'
#  'FreetoPlay-Indie-Sports-Strategy'
#  'Animation&amp;Modeling-Design&amp;Illustration-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-RPG-Simulation-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Adventure-Casual-FreetoPlay-RPG-Simulation-Strategy'
#  'Racing-Simulation-Sports-EarlyAccess' 'Casual-FreetoPlay-RPG-Strategy'
#  'MassivelyMultiplayer-Simulation-Sports-EarlyAccess'
#  'Adventure-Casual-Indie-Strategy-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-RPG-Simulation-EarlyAccess'
#  'Action-Adventure-MassivelyMultiplayer-Simulation-EarlyAccess'
#  'Casual-Indie-Racing-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Simulation-Sports-EarlyAccess'
#  'Action-Adventure-Casual-FreetoPlay-Indie-Simulation'
#  'Adventure-Indie-MassivelyMultiplayer-RPG-Simulation-EarlyAccess'
#  'Action-FreetoPlay-Indie-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Racing-RPG-Simulation-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education'
#  'FreetoPlay-Indie-Racing-Simulation'
#  'Adventure-FreetoPlay-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'FreetoPlay-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-PhotoEditing-SoftwareTraining-Utilities-VideoProduction'
#  'Design&amp;Illustration-SoftwareTraining-Utilities'
#  'Casual-FreetoPlay-Indie-Racing'
#  'Adventure-Casual-RPG-Simulation-Strategy'
#  'FreetoPlay-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Action-Adventure-Casual-Indie-MassivelyMultiplayer-EarlyAccess'
#  'Casual-FreetoPlay-Indie-EarlyAccess' 'AudioProduction-Education'
#  'Action-Casual-FreetoPlay-Indie-Racing-Simulation-Sports-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-RPG-Simulation-Sports'
#  'Animation&amp;Modeling-Design&amp;Illustration-PhotoEditing'
#  'FreetoPlay-Indie-Racing-Simulation-Sports'
#  'MassivelyMultiplayer-RPG-Simulation'
#  'Action-Adventure-Indie-MassivelyMultiplayer-Simulation-Strategy-EarlyAccess'
#  'Action-FreetoPlay-Indie-Strategy-EarlyAccess'
#  'Action-Casual-FreetoPlay-Indie-Simulation'
#  'Action-Indie-MassivelyMultiplayer-Racing-Simulation-Sports'
#  'Adventure-Indie-RPG-Simulation-Strategy-EarlyAccess'
#  'Action-FreetoPlay-MassivelyMultiplayer-Racing-EarlyAccess'
#  'Action-Adventure-Indie-MassivelyMultiplayer'
#  'MassivelyMultiplayer-Simulation'
#  'Casual-FreetoPlay-Indie-MassivelyMultiplayer-RPG-EarlyAccess'
#  'Adventure-FreetoPlay-Indie-EarlyAccess'
#  'Adventure-Casual-Indie-MassivelyMultiplayer-Strategy'
#  'Action-Simulation-EarlyAccess'
#  'Action-FreetoPlay-MassivelyMultiplayer-RPG-Strategy-EarlyAccess'
#  'Adventure-Casual-FreetoPlay-Indie-RPG-Simulation'
#  'Adventure-Casual-Racing' 'Action-Adventure-Casual-Simulation-Strategy'
#  'Animation&amp;Modeling-Design&amp;Illustration-Education-SoftwareTraining-Utilities-VideoProduction'
#  'Action-MassivelyMultiplayer-Simulation-EarlyAccess'
#  'PhotoEditing-SoftwareTraining-Utilities'
#  'Action-MassivelyMultiplayer-Racing-RPG-Simulation-EarlyAccess'
#  'Action-Adventure-Casual-Indie-Racing-RPG-Simulation-Sports-Strategy'
#  'Education-SoftwareTraining-Utilities-EarlyAccess'
#  'Adventure-Casual-Indie-MassivelyMultiplayer-Simulation'
#  'MassivelyMultiplayer-Strategy'
#  'Action-Adventure-MassivelyMultiplayer-Simulation'
#  'Action-Casual-Indie-Racing-Strategy'
#  'Animation&amp;Modeling-Design&amp;Illustration-Utilities-WebPublishing'
#  'Action-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Casual-Indie-RPG-Strategy-EarlyAccess'
#  'PhotoEditing-Utilities-VideoProduction' 'Action-Indie-RPG-Sports'
#  'Action-Adventure-Indie-Racing-Simulation-Sports-EarlyAccess'
#  'Action-Casual-Indie-MassivelyMultiplayer-Strategy-EarlyAccess'
#  'Animation&amp;Modeling-Design&amp;Illustration-PhotoEditing-SoftwareTraining-Utilities-VideoProduction'
#  'Action-FreetoPlay-MassivelyMultiplayer-RPG-Simulation-Strategy'
#  'Action-Casual-FreetoPlay-MassivelyMultiplayer-RPG-Simulation-Strategy'
#  'Adventure-Racing' 'Action-Adventure-Casual-FreetoPlay-Racing'
#  'Animation&amp;Modeling-Design&amp;Illustration-PhotoEditing-VideoProduction'
#  'Casual-Indie-MassivelyMultiplayer-Racing'
#  'Casual-FreetoPlay-Indie-MassivelyMultiplayer-RPG'
#  'Action-Adventure-FreetoPlay-Indie-RPG-Simulation-Strategy'
#  'Action-FreetoPlay-Indie-RPG-EarlyAccess'
#  'FreetoPlay-Indie-MassivelyMultiplayer-Racing-RPG-Strategy'
#  'Action-FreetoPlay-Indie-Sports-Strategy-EarlyAccess'
#  'Action-FreetoPlay-Indie-Sports-Strategy'
#  'Action-Adventure-Casual-FreetoPlay-Indie-MassivelyMultiplayer'
#  'Adventure-FreetoPlay-MassivelyMultiplayer-RPG-Simulation'
#  'Education-SoftwareTraining-Utilities-VideoProduction'
#  'Action-Adventure-Casual-FreetoPlay-Indie-MassivelyMultiplayer-Racing-RPG-Simulation-Sports-Strategy'
#  'Adventure-Racing-Simulation' 'Adventure-EarlyAccess-Indie-RPG'
#  'Casual-FreetoPlay-Indie-RPG-Strategy'
#  'Design&amp;Illustration-Education-SoftwareTraining-Utilities'
#  'Casual-EarlyAccess-Indie-Simulation-Strategy' 'Action-Racing-RPG'
#  'Action-EarlyAccess-FreetoPlay-Strategy'
#  'Action-Adventure-EarlyAccess-Indie-Strategy'
#  'AudioProduction-SoftwareTraining' 'EarlyAccess-Indie'
#  'Action-Casual-FreetoPlay-MassivelyMultiplayer-RPG-Simulation'
#  'Adventure-Indie-Casual' 'Action-Adventure-RPG-Indie'
#  'FreetoPlay-Action-Strategy-Indie-Sports' 'Adventure-Strategy-Indie'
#  'Action-Strategy-Simulation' 'Sports-Simulation'
#  'Action-Adventure-Indie-Casual' 'Sports-Casual' 'Sports-Action'
#  'RPG-Indie-Casual' 'Strategy-Action-Indie' 'Casual-Strategy-Indie'
#  'Action-Casual-FreetoPlay-Indie-Racing'
#  'Adventure-Casual-RPG-Simulation-EarlyAccess']

# %%
df_steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30054 entries, 88310 to 120443
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   publisher       30054 non-null  object
#  1   genres          30054 non-null  object
#  2   app_name        30054 non-null  object
#  3   title           30054 non-null  object
#  4   url             30054 non-null  object
#  5   release_date    30054 non-null  int64
#  6   tags            30054 non-null  object
#  7   reviews_url     30054 non-null  object
#  8   discount_price  30054 non-null  float64
#  9   specs           30054 non-null  object
#  10  price           30054 non-null  float64
#  11  early_access    30054 non-null  float64
#  12  id              30054 non-null  float64
#  13  developer       30054 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 3.4+ MB

# %%
df_steam_games.to_csv('steam_games', index= False)
